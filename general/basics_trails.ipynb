# %%
from os import lstat

import sys

from pexpect.replwrap import python

list1 = ["Test", "tester1", "tester2", "tester3"]
list2 = ["QA1", "QA2", list1]
list3 = ["QA3", "QA4"]
print(list1)
print(list2)
list3.extend(list1)
print(list3)
# Out:
# ['Test', 'tester1', 'tester2', 'tester3']
# ['QA1', 'QA2', ['Test', 'tester1', 'tester2', 'tester3']]
# ['QA3', 'QA4', 'Test', 'tester1', 'tester2', 'tester3']

# %%
set1 = {1,2,3,3,5,1,2}
print(31 in set1)
# Out:
# False

# %%
str_val = "Tester India"
print(str_val[:-5:-1])
print(str_val[::-1])
# Out:
# aidn
# aidnI retseT

# %%
str_val1 = "aaa4"
print(str_val1.isalpha())
print(str_val1.isalnum())
# Out:
# False
# True

# %%
lst=[5,25,21,321]

print(*lst)
def get_int(*input_values):
    print(input_values)

get_int(*lst)
# Out:
# 5 25 21 321
# (5, 25, 21, 321)

# %%
import sys
temp_var = 10
def my_method():
    global temp_var
    temp_var=20
    print(f"inside {sys._getframe().f_code.co_name} - var: {temp_var}")

print(temp_var)
my_method()
print(temp_var)
#print(sys.version)
# Out:
# 10
# inside my_method - var: 20
# 20
